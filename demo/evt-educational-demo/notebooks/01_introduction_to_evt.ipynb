# %% [markdown]
# # 1. Введение в EVT
#
# **Цели:** создать воспроизводимый ряд и увидеть редкие события. Предпосылка: стационарный фон AR(1).

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / "src"))

# %%
from evt_demo import generate_time_series_with_extreme_events
from evt_demo.visualization import plot_time_series_with_extremes
series, truth = generate_time_series_with_extreme_events(seed=42)
fig, ax = plot_time_series_with_extremes(series, truth, save_path="../figures/notebook_01_series.png")
int(truth.sum())
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# 9

# %% [markdown]
# Обычная модель центральной части распределения не заменяет модель хвоста. Здесь метки известны только потому, что события внедрены искусственно.
#
# **Самопроверка:** 1) Что меняет $\phi$? 2) Зачем фиксировать seed? 3) Почему синтетический результат нельзя прямо переносить на реальные данные?
